# %%
// API of the 7 wonders of the world
const wonders = [
    {
      name: "Great Wall of China",
      country: "China",
      facts: [
        "It is the longest man-made structure in the world.",
        "It was built over many centuries, starting in the 7th century BC.",
        "It is made up of many different sections, each of which was built by a different dynasty.",
      ],
    },
    {
      name: "Chichen Itza",
      country: "Mexico",
      facts: [
        "It is an ancient Mayan city that was built over 1,000 years ago.",
        "It is home to the iconic Kukulkan pyramid, which is also known as El Castillo.",
        "It was a major center of trade and culture for the Mayan people.",
      ],
    },
    {
      name: "Machu Picchu",
      country: "Peru",
      facts: [
        "It is an ancient Inca city that was built in the 15th century.",
        "It is located high in the Andes mountains, and is surrounded by lush cloud forests.",
        "It was abandoned by the Incas in the 16th century, and was not rediscovered until the 20th century.",
    },
    {
      name: "Colosseum",
      country: "Italy",
      facts: [
        "It is an ancient Roman amphitheater that was built in the 1st century AD.",
        "It was used for gladiatorial contests and other public events.",
        "It is one of the most iconic landmarks in the world.",
    },
    {
      name: "Taj Mahal",
      country: "India",
      facts: [
        "It is a white marble mausoleum that was built in the 17th century.",
        "It was built by Mughal emperor Shah Jahan in memory of his beloved wife, Mumtaz Mahal.",
        "It is one of the most beautiful buildings in the world.",
    },
    {
      name: "Christ the Redeemer",
      country: "Brazil",
      facts: [
        "It is a statue of Jesus Christ that is located on Corcovado Mountain in Rio de Janeiro.",
        "It is one of the largest statues of Jesus Christ in the world.",
        "It is a popular tourist destination, and offers stunning views of the city.",
    },
    {
      name: "Petra",
      country: "Jordan",
      facts: [
        "It is an ancient Nabatean city that was carved into the sandstone cliffs over 2,000 years ago.",
        "It is home to many elaborate temples, tombs, and other structures.",
        "It was abandoned in the 14th century, and was not rediscovered until the 19th century.",
    },
  ];
  
  // Generate a clickable button
  const button = document.createElement("button");
  button.textContent = "Click here to guess the country!";
  button.addEventListener("click", function() {
    // Prompt the user to enter in which wonder of the world they think it is
    const wonder = prompt("Which wonder of the world do you think this is?");
  
    // Check if the user's guess is correct
    if (wonder === button.getAttribute("wonder")) {
      alert("Correct! This is the " + button.getAttribute("wonder") + ".");
    } else {
      alert("Incorrect. The correct answer is the " + button.getAttribute("wonder") + ".");
    }
  });
  
  // Display the button
  document.body.appendChild(button);
  
  // Randomly select a wonder of the world
  const randomWonder = wonders[Math.floor(Math.random() * wonders.length)];
  
  // Set the button's wonder attribute
  button.setAttribute("wonder", randomWonder.name);
  
  // Display a fact about the wonder of the world
  document.body.innerHTML += "<p>" + randomWonder.facts[Math.floor(Math.random() * randomWonder.facts.length)] + "</p>";
